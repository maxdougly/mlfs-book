# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"> **Air Quality** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 04: Batch Inference</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Download model and batch inference data
# 2. Make predictions, generate PNG for forecast
# 3. Store predictions in a monitoring feature group adn generate PNG for hindcast

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
import datetime
import pandas as pd
from xgboost import XGBRegressor
import hopsworks
import json
from functions import util
import os

# %%
today = datetime.datetime.now() - datetime.timedelta(0)
tomorrow = today + datetime.timedelta(days = 1)
today
# Out:
# datetime.datetime(2024, 11, 20, 21, 13, 46, 918527)

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
os.environ["HOPSWORKS_API_KEY"] = "hnoLoEhnnXr0NIlt.hIAb7iCp86nnF4QNTjpsgJrURRwFTMG80Pe0JrMQjwa31eQCnTEr0cVjtyb8K9Tn"

project = hopsworks.login(project="id2223_labs_24")
fs = project.get_feature_store() 

secrets = util.secrets_api(project.name)
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1161371
# Connected. Call `.close()` to terminate connection gracefully.
# Connected. Call `.close()` to terminate connection gracefully.

# %% [markdown]
# ## <span style="color:#ff5f27;"> ⚙️ Feature View Retrieval</span>

# %%
feature_view = fs.get_feature_view(
    name='air_quality_fv',
    version=2,
)

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Download the model from Model Registry</span>

# %%
mr = project.get_model_registry()

retrieved_model = mr.get_model(
    name="air_quality_xgboost_model",
    version=2,
)

# Download the saved model artifacts to a local directory
saved_model_dir = retrieved_model.download()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
# Downloading model artifact (0 dirs, 3 files)... DONE

# %%
# Loading the XGBoost regressor model and label encoder from the saved model directory
# retrieved_xgboost_model = joblib.load(saved_model_dir + "/xgboost_regressor.pkl")
retrieved_xgboost_model = XGBRegressor()

retrieved_xgboost_model.load_model(saved_model_dir + "/model.json")

# Displaying the retrieved XGBoost regressor model
retrieved_xgboost_model
# Out:
# XGBRegressor(base_score='2.425612E1', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              feature_types=['float', 'float', 'float', 'float'], gamma=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## <span style="color:#ff5f27;">✨ Get Weather Forecast Features with Feature View   </span>

# %%
air_quality_lagged_fg = fs.get_feature_group(
    name='air_quality_lagged',
    version=1,
)

# %%
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)
batch_data = weather_fg.filter(weather_fg.date >= today).read()
batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.86s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-21 00:00:00+00:00                -3.15                0.3
# 1 2024-11-22 00:00:00+00:00                -5.35                0.0
# 2 2024-11-24 00:00:00+00:00                 3.25                0.0
# 3 2024-11-23 00:00:00+00:00                -2.65                0.0
# 4 2024-11-25 00:00:00+00:00                 9.95                0.1
# 5 2024-11-26 00:00:00+00:00                 8.35                0.0
# 6 2024-11-27 00:00:00+00:00                 6.55                0.1
# 7 2024-11-28 00:00:00+00:00                 1.35                0.0
# 8 2024-11-29 00:00:00+00:00                 0.60                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city
# 0           28.585449                   301.087433  stockholm
# 1           15.188415                   264.559753  stockholm
# 2           15.315873                   150.422256  stockholm
# 3           11.901798                   273.468170  stockholm
# 4           20.124611                   206.564987  stockholm
# 5           16.575644                   214.380402  stockholm
# 6           11.753877                   207.349792  stockholm
# 7           13.896187                   323.426880  stockholm
# 8            3.240000                   180.000000  stockholm

# %%
lagged_data = air_quality_lagged_fg.read()
latest_lagged_row = lagged_data.sort_values(by='date', ascending=False).iloc[0] 

batch_data['pm25lag1'] = latest_lagged_row['pm25lag1']
batch_data['pm25lag2'] = latest_lagged_row['pm25lag2']
batch_data['pm25lag3'] = latest_lagged_row['pm25lag3']
batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.08s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-21 00:00:00+00:00                -3.15                0.3
# 1 2024-11-22 00:00:00+00:00                -5.35                0.0
# 2 2024-11-24 00:00:00+00:00                 3.25                0.0
# 3 2024-11-23 00:00:00+00:00                -2.65                0.0
# 4 2024-11-25 00:00:00+00:00                 9.95                0.1
# 5 2024-11-26 00:00:00+00:00                 8.35                0.0
# 6 2024-11-27 00:00:00+00:00                 6.55                0.1
# 7 2024-11-28 00:00:00+00:00                 1.35                0.0
# 8 2024-11-29 00:00:00+00:00                 0.60                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  pm25lag1  \
# 0           28.585449                   301.087433  stockholm      19.0
# 1           15.188415                   264.559753  stockholm      19.0
# 2           15.315873                   150.422256  stockholm      19.0
# 3           11.901798                   273.468170  stockholm      19.0
# 4           20.124611                   206.564987  stockholm      19.0
# 5           16.575644                   214.380402  stockholm      19.0
# 6           11.753877                   207.349792  stockholm      19.0
# 7           13.896187                   323.426880  stockholm      19.0
# 8            3.240000                   180.000000  stockholm      19.0
#
#    pm25lag2  pm25lag3
# 0      17.0      15.0
# 1      17.0      15.0
# 2      17.0      15.0
# 3      17.0      15.0
# 4      17.0      15.0
# 5      17.0      15.0
# 6      17.0      15.0
# 7      17.0      15.0
# 8      17.0      15.0

# %%
batch_data.columns
# Out:
# Index(['date', 'temperature_2m_mean', 'precipitation_sum',
#        'wind_speed_10m_max', 'wind_direction_10m_dominant', 'city', 'pm25lag1',
#        'pm25lag2', 'pm25lag3'],
#       dtype='object')

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         9 non-null      datetime64[us, UTC]
#  1   temperature_2m_mean          9 non-null      float32
#  2   precipitation_sum            9 non-null      float32
#  3   wind_speed_10m_max           9 non-null      float32
#  4   wind_direction_10m_dominant  9 non-null      float32
#  5   city                         9 non-null      object
#  6   pm25lag1                     9 non-null      float64
#  7   pm25lag2                     9 non-null      float64
#  8   pm25lag3                     9 non-null      float64
# dtypes: datetime64[us, UTC](1), float32(4), float64(3), object(1)
# memory usage: 632.0+ bytes

# %%
# Retrieve model features
model_features = retrieved_xgboost_model.get_booster().feature_names

# Preprocess 'date' column
# Ensure the 'date' column is in UTC and convert to seconds since epoch
# batch_data['date'] = batch_data['date'].dt.tz_convert('UTC')  # Ensure it's in UTC
# batch_data['date'] = batch_data['date'].view('int64') // 10**9  # Convert to seconds since epoch


# Encode 'city' column
batch_data['city'] = batch_data['city'].astype('category').cat.codes

# Ensure the batch data has the features expected by the model
for i in range(len(batch_data)):
    # Select only model features in the correct order
    input_data = batch_data.loc[i, model_features].to_frame().T
    
    # Ensure all data is float for the model
    input_data = input_data.astype(float)
    
    # Predict pm25
    predicted_pm25 = retrieved_xgboost_model.predict(input_data)[0]
    batch_data.loc[i, 'predicted_pm25'] = predicted_pm25

    # Update lagged features
    if i + 1 < len(batch_data):
        batch_data.loc[i + 1, 'pm25lag1'] = predicted_pm25
        batch_data.loc[i + 1, 'pm25lag2'] = batch_data.loc[i, 'pm25lag1']
        batch_data.loc[i + 1, 'pm25lag3'] = batch_data.loc[i, 'pm25lag2']

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Making the predictions</span>

# %%
batch_data['predicted_pm25'] = retrieved_xgboost_model.predict(
    batch_data[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant']])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-21 00:00:00+00:00                -3.15                0.3
# 1 2024-11-22 00:00:00+00:00                -5.35                0.0
# 2 2024-11-24 00:00:00+00:00                 3.25                0.0
# 3 2024-11-23 00:00:00+00:00                -2.65                0.0
# 4 2024-11-25 00:00:00+00:00                 9.95                0.1
# 5 2024-11-26 00:00:00+00:00                 8.35                0.0
# 6 2024-11-27 00:00:00+00:00                 6.55                0.1
# 7 2024-11-28 00:00:00+00:00                 1.35                0.0
# 8 2024-11-29 00:00:00+00:00                 0.60                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant  city   pm25lag1  \
# 0           28.585449                   301.087433     0  19.000000
# 1           15.188415                   264.559753     0  22.852205
# 2           15.315873                   150.422256     0  22.318966
# 3           11.901798                   273.468170     0  37.620617
# 4           20.124611                   206.564987     0  23.701683
# 5           16.575644                   214.380402     0  23.760963
# 6           11.753877                   207.349792     0  37.170254
# 7           13.896187                   323.426880     0  21.118057
# 8            3.240000                   180.000000     0  21.705349
#
#     pm25lag2   pm25lag3  predicted_pm25
# 0  17.000000  15.000000       22.852205
# 1  19.000000  17.000000       22.318966
# 2  22.852205  19.000000       37.620617
# 3  22.318966  22.852205       23.701683
# 4  37.620617  22.318966       23.760963
# 5  23.701683  37.620617       37.170254
# 6  23.760963  23.701683       21.118057
# 7  37.170254  23.760963       21.705349
# 8  21.118057  37.170254       24.897108

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         9 non-null      datetime64[us, UTC]
#  1   temperature_2m_mean          9 non-null      float32
#  2   precipitation_sum            9 non-null      float32
#  3   wind_speed_10m_max           9 non-null      float32
#  4   wind_direction_10m_dominant  9 non-null      float32
#  5   city                         9 non-null      int8
#  6   pm25lag1                     9 non-null      float64
#  7   pm25lag2                     9 non-null      float64
#  8   pm25lag3                     9 non-null      float64
#  9   predicted_pm25               9 non-null      float32
# dtypes: datetime64[us, UTC](1), float32(5), float64(3), int8(1)
# memory usage: 605.0 bytes

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Saving the predictions (for monitoring) to a Feature Group</span>

# %%
batch_data['street'] = street
batch_data['city'] = city
batch_data['country'] = country
# Fill in the number of days before the date on which you made the forecast (base_date)
batch_data['days_before_forecast_day'] = range(1, len(batch_data)+1)
batch_data = batch_data.sort_values(by=['date'])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-21 00:00:00+00:00                -3.15                0.3
# 1 2024-11-22 00:00:00+00:00                -5.35                0.0
# 3 2024-11-23 00:00:00+00:00                -2.65                0.0
# 2 2024-11-24 00:00:00+00:00                 3.25                0.0
# 4 2024-11-25 00:00:00+00:00                 9.95                0.1
# 5 2024-11-26 00:00:00+00:00                 8.35                0.0
# 6 2024-11-27 00:00:00+00:00                 6.55                0.1
# 7 2024-11-28 00:00:00+00:00                 1.35                0.0
# 8 2024-11-29 00:00:00+00:00                 0.60                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city   pm25lag1  \
# 0           28.585449                   301.087433  stockholm  19.000000
# 1           15.188415                   264.559753  stockholm  22.852205
# 3           11.901798                   273.468170  stockholm  37.620617
# 2           15.315873                   150.422256  stockholm  22.318966
# 4           20.124611                   206.564987  stockholm  23.701683
# 5           16.575644                   214.380402  stockholm  23.760963
# 6           11.753877                   207.349792  stockholm  37.170254
# 7           13.896187                   323.426880  stockholm  21.118057
# 8            3.240000                   180.000000  stockholm  21.705349
#
#     pm25lag2   pm25lag3  predicted_pm25            street country  \
# 0  17.000000  15.000000       22.852205  st eriksgatan 83  sweden
# 1  19.000000  17.000000       22.318966  st eriksgatan 83  sweden
# 3  22.318966  22.852205       23.701683  st eriksgatan 83  sweden
# 2  22.852205  19.000000       37.620617  st eriksgatan 83  sweden
# 4  37.620617  22.318966       23.760963  st eriksgatan 83  sweden
# 5  23.701683  37.620617       37.170254  st eriksgatan 83  sweden
# 6  23.760963  23.701683       21.118057  st eriksgatan 83  sweden
# 7  37.170254  23.760963       21.705349  st eriksgatan 83  sweden
# 8  21.118057  37.170254       24.897108  st eriksgatan 83  sweden
#
#    days_before_forecast_day
# 0                         1
# 1                         2
# 3                         4
# 2                         3
# 4                         5
# 5                         6
# 6                         7
# 7                         8
# 8                         9

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         9 non-null      datetime64[us, UTC]
#  1   temperature_2m_mean          9 non-null      float32
#  2   precipitation_sum            9 non-null      float32
#  3   wind_speed_10m_max           9 non-null      float32
#  4   wind_direction_10m_dominant  9 non-null      float32
#  5   city                         9 non-null      object
#  6   pm25lag1                     9 non-null      float64
#  7   pm25lag2                     9 non-null      float64
#  8   pm25lag3                     9 non-null      float64
#  9   predicted_pm25               9 non-null      float32
#  10  street                       9 non-null      object
#  11  country                      9 non-null      object
#  12  days_before_forecast_day     9 non-null      int64
# dtypes: datetime64[us, UTC](1), float32(5), float64(3), int64(1), object(3)
# memory usage: 828.0+ bytes

# %% [markdown]
# ### Create Forecast Graph
# Draw a graph of the predictions with dates as a PNG and save it to the github repo
# Show it on github pages

# %%
file_path = "../../docs/air-quality/assets/img/pm25_forecast.png"
plt = util.plot_air_quality_forecast(city, street, batch_data, file_path)
plt.show()

# %%
# Get or create feature group
monitor_fg = fs.get_or_create_feature_group(
    name='aq_predictions',
    description='Air Quality prediction monitoring',
    version=1,
    primary_key=['city','street','date','days_before_forecast_day'],
    event_time="date"
)

# %%
batch_data = batch_data.drop(columns=['pm25lag1', 'pm25lag2', 'pm25lag3'])

# %%
monitor_fg.insert(batch_data, write_options={"wait_for_job": True})
# Out:
# Uploading Dataframe: 0.00% |          | Rows 0/9 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: aq_predictions_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/1161371/jobs/named/aq_predictions_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x1db48367220>, None)

# %%
monitor_fg.read().sort_values('date')
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.75s)
#                         date  temperature_2m_mean  precipitation_sum  \
# 9  2024-11-17 00:00:00+00:00                 6.45                0.0
# 1  2024-11-18 00:00:00+00:00                 2.50                0.0
# 5  2024-11-19 00:00:00+00:00                 0.80                0.0
# 10 2024-11-19 00:00:00+00:00                 1.25                0.0
# 6  2024-11-20 00:00:00+00:00                 1.25                0.4
# 22 2024-11-20 00:00:00+00:00                 1.25                0.1
# 15 2024-11-20 00:00:00+00:00                 1.20                0.2
# 8  2024-11-21 00:00:00+00:00                -3.15                0.3
# 4  2024-11-22 00:00:00+00:00                -5.35                0.0
# 0  2024-11-23 00:00:00+00:00                -0.40                0.0
# 20 2024-11-23 00:00:00+00:00                -2.65                0.0
# 14 2024-11-23 00:00:00+00:00                -2.95                0.0
# 3  2024-11-24 00:00:00+00:00                 1.35                0.3
# 12 2024-11-24 00:00:00+00:00                 1.40                1.0
# 19 2024-11-24 00:00:00+00:00                 3.25                0.0
# 23 2024-11-25 00:00:00+00:00                 9.95                0.1
# 13 2024-11-25 00:00:00+00:00                 0.95                0.4
# 2  2024-11-25 00:00:00+00:00                 1.20                0.0
# 18 2024-11-26 00:00:00+00:00                 8.35                0.0
# 11 2024-11-26 00:00:00+00:00                 2.00                0.6
# 7  2024-11-26 00:00:00+00:00                -1.95                0.0
# 17 2024-11-27 00:00:00+00:00                 0.45                0.0
# 24 2024-11-27 00:00:00+00:00                 6.55                0.1
# 16 2024-11-27 00:00:00+00:00                -0.10                0.0
# 25 2024-11-28 00:00:00+00:00                 1.35                0.0
# 21 2024-11-28 00:00:00+00:00                 1.90                0.0
# 26 2024-11-29 00:00:00+00:00                 0.60                0.0
#
#     wind_speed_10m_max  wind_direction_10m_dominant       city  \
# 9            18.388212                   246.948669  stockholm
# 1            10.895576                   277.594543  stockholm
# 5             2.620839                   105.945465  stockholm
# 10            3.617955                    95.710503  stockholm
# 6            25.932495                    13.650437  stockholm
# 22           24.087738                   350.537750  stockholm
# 15           24.640940                    11.802421  stockholm
# 8            28.585449                   301.087433  stockholm
# 4            15.188415                   264.559753  stockholm
# 0            13.910169                   280.437408  stockholm
# 20           11.901798                   273.468170  stockholm
# 14           14.512064                   262.875092  stockholm
# 3            18.161278                   129.369293  stockholm
# 12           27.248455                   136.605957  stockholm
# 19           15.315873                   150.422256  stockholm
# 23           20.124611                   206.564987  stockholm
# 13           16.323528                   311.423584  stockholm
# 2            18.278645                   302.124969  stockholm
# 18           16.575644                   214.380402  stockholm
# 11           20.771093                   244.323227  stockholm
# 7            11.435313                   331.821503  stockholm
# 17            5.692100                   288.435028  stockholm
# 24           11.753877                   207.349792  stockholm
# 16           19.453327                   308.990997  stockholm
# 25           13.896187                   323.426880  stockholm
# 21           14.512064                   246.614761  stockholm
# 26            3.240000                   180.000000  stockholm
#
#     predicted_pm25            street country  days_before_forecast_day
# 9        23.755095  st eriksgatan 83  sweden                         1
# 1        33.488567  st eriksgatan 83  sweden                         3
# 5        37.041576  st eriksgatan 83  sweden                         4
# 10       32.618816  st eriksgatan 83  sweden                         3
# 6        17.029465  st eriksgatan 83  sweden                         9
# 22       24.363827  st eriksgatan 83  sweden                         7
# 15       10.786509  st eriksgatan 83  sweden                         8
# 8        22.852205  st eriksgatan 83  sweden                         1
# 4        22.318966  st eriksgatan 83  sweden                         2
# 0        19.934998  st eriksgatan 83  sweden                         6
# 20       23.701683  st eriksgatan 83  sweden                         4
# 14       30.822187  st eriksgatan 83  sweden                         5
# 3        36.526199  st eriksgatan 83  sweden                         5
# 12       41.393402  st eriksgatan 83  sweden                         4
# 19       37.620617  st eriksgatan 83  sweden                         3
# 23       23.760963  st eriksgatan 83  sweden                         5
# 13       22.219053  st eriksgatan 83  sweden                         6
# 2        29.976440  st eriksgatan 83  sweden                         7
# 18       37.170254  st eriksgatan 83  sweden                         6
# 11       17.981838  st eriksgatan 83  sweden                         7
# 7        36.281456  st eriksgatan 83  sweden                         8
# 17       22.418369  st eriksgatan 83  sweden                         8
# 24       21.118057  st eriksgatan 83  sweden                         7
# 16       16.761690  st eriksgatan 83  sweden                         9
# 25       21.705349  st eriksgatan 83  sweden                         8
# 21       27.964216  st eriksgatan 83  sweden                         9
# 26       24.897108  st eriksgatan 83  sweden                         9

# %%
# We will create a hindcast chart for  only the forecasts made 1 day beforehand
monitoring_df = monitor_fg.filter(monitor_fg.days_before_forecast_day == 1).read()
monitoring_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.36s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-21 00:00:00+00:00                -3.15                0.3
# 1 2024-11-17 00:00:00+00:00                 6.45                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  predicted_pm25  \
# 0           28.585449                   301.087433  stockholm       22.852205
# 1           18.388212                   246.948669  stockholm       23.755095
#
#              street country  days_before_forecast_day
# 0  st eriksgatan 83  sweden                         1
# 1  st eriksgatan 83  sweden                         1

# %%
air_quality_fg = fs.get_feature_group(
    name='air_quality',
    version=1,
)
air_quality_df = air_quality_fg.read()
air_quality_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.35s)
#                           date  pm25 country       city            street  \
# 0    2022-03-14 00:00:00+00:00  76.0  sweden  stockholm  st eriksgatan 83
# 1    2021-03-14 00:00:00+00:00  42.0  sweden  stockholm  st eriksgatan 83
# 2    2020-01-06 00:00:00+00:00  12.0  sweden  stockholm  st eriksgatan 83
# 3    2021-03-07 00:00:00+00:00  19.0  sweden  stockholm  st eriksgatan 83
# 4    2020-05-30 00:00:00+00:00  11.0  sweden  stockholm  st eriksgatan 83
# ...                        ...   ...     ...        ...               ...
# 2179 2023-05-12 00:00:00+00:00  36.0  sweden  stockholm  st eriksgatan 83
# 2180 2024-11-17 00:00:00+00:00  15.0  sweden  stockholm  st eriksgatan 83
# 2181 2024-11-18 00:00:00+00:00  17.0  sweden  stockholm  st eriksgatan 83
# 2182 2024-11-19 00:00:00+00:00  19.0  sweden  stockholm  st eriksgatan 83
# 2183 2024-11-20 00:00:00+00:00  19.0  sweden  stockholm  st eriksgatan 83
#
#                                     url
# 0     https://api.waqi.info/feed/@10523
# 1     https://api.waqi.info/feed/@10523
# 2     https://api.waqi.info/feed/@10523
# 3     https://api.waqi.info/feed/@10523
# 4     https://api.waqi.info/feed/@10523
# ...                                 ...
# 2179  https://api.waqi.info/feed/@10523
# 2180  https://api.waqi.info/feed/@10523
# 2181  https://api.waqi.info/feed/@10523
# 2182  https://api.waqi.info/feed/@10523
# 2183  https://api.waqi.info/feed/@10523
#
# [2184 rows x 6 columns]

# %%
outcome_df = air_quality_df[['date', 'pm25']]
preds_df =  monitoring_df[['date', 'predicted_pm25']]

hindcast_df = pd.merge(preds_df, outcome_df, on="date")
hindcast_df = hindcast_df.sort_values(by=['date'])

# If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
if len(hindcast_df) == 0:
    hindcast_df = util.backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
    
hindcast_df
# Out:
#                        date  predicted_pm25  pm25
# 0 2024-11-17 00:00:00+00:00       23.755095  15.0

# %% [markdown]
# ### Plot the Hindcast comparing predicted with forecasted values (1-day prior forecast)
#
# __This graph will be empty to begin with - this is normal.__
#
# After a few days of predictions and observations, you will get data points in this graph.

# %%
file_path = "../../docs/air-quality/assets/img/pm25_hindcast_1day.png"
plt = util.plot_air_quality_forecast(city, street, hindcast_df, file_path, hindcast=True)
plt.show()

# %% [markdown]
# ---
